# %%
from Note import Note

# %%
from matplotlib import pyplot as plt

% matplotlib inline

plt.plot(Note(440, 0.3).get_data())

# %%
import numpy as np

from ADSR import ADSR
from constants import SAMPLES_PER_SECOND

adsr = ADSR(0.1, 0.2, 0.7, 0.3)
plt.plot(adsr.apply_linear(np.ones(SAMPLES_PER_SECOND)))

# %%
plt.plot(adsr.apply_exponential(np.ones(SAMPLES_PER_SECOND)))
