# %% [markdown]
# ## Chapter 3
# # Musical Scales, Tuning, and Intonation

# %%
import sys
sys.path.append('../')

from sound_util import Note, Notes, render_notes, render_overlapping_notes

# %%
# just testing out my Note classes...
render_notes([(880, 0.4), (440, 0.2), (660, 0.6)] * 3 + [(220, 1)])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
render_overlapping_notes([
    [(880, 0.4), (440, 0.2), (660, 0.6)] * 3 + [(220, 1, 0.5)],
    [(1340, 0.2), (330, 0.3), (220, 0.2), (0, 0.2), Note(1100, 0.3, release_seconds=0.01)] * 3 + [(1100, 1, 0.5)]
])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
