# %% [markdown]
# # Chapter 17
# ## Working with APIs

# %% [markdown]
# ### Using a Web API

# %% [markdown]
# See <https://api.github.com/search/repositories?q=language:python&sort=stars>

# %% [markdown]
# #### Processing an API Response

# %%
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=starts'
r = requests.get(url)
print('Status code:', r.status_code)
# Out:
# Status code:  200

# %%
response_dict = r.json()
print(response_dict.keys())
# Out:
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %% [markdown]
# #### Working with the response dictionary

# %%
print('Total repositories: ', response_dict['total_count'])

repo_dicts = response_dict['items']
print('Repositories returned:', len(repo_dicts))
# Out:
# Total repositories:  2180553
# Repositories returned: 30

# %%
repo_dict = repo_dicts[0]
print('\nKeys:', len(repo_dict))
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Keys: 72
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# trees_url
# updated_at
# url
# watchers
# watchers_count

# %%
print('\nSelected information about first repository:')
print('Name:', repo_dict['name'])
print('Owner:', repo_dict['owner']['login'])
print('Stars:', repo_dict['stargazers_count'])
print('Repository:', repo_dict['html_url'])
print('Created:', repo_dict['created_at'])
print('Updated:', repo_dict['updated_at'])
print('Description:', repo_dict['description'])
# Out:
# Selected information about first repository:
# Name: awesome-python
# Owner: vinta
# Stars: 42210
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2017-12-11T00:16:30Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources

# %% [markdown]
# #### Summarizing the top repositories

# %%
print('\nSelected information about each repository:')
for repo_dict in repo_dicts:
    print('\nName:', repo_dict['name'])
    print('Owner:', repo_dict['owner']['login'])
    print('Stars:', repo_dict['stargazers_count'])
    print('Repository:', repo_dict['html_url'])
    print('Created:', repo_dict['created_at'])
    print('Updated:', repo_dict['updated_at'])
    print('Description:', repo_dict['description'])
# Out:
# Selected information about each repository:
#
# Name: awesome-python
# Owner: vinta
# Stars: 42210
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2017-12-11T00:16:30Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources
#
# Name: httpie
# Owner: jakubroztocil
# Stars: 32963
# Repository: https://github.com/jakubroztocil/httpie
# Created: 2012-02-25T12:39:13Z
# Updated: 2017-12-11T01:02:15Z
# Description: Modern command line HTTP client – user-friendly curl alternative with intuitive UI, JSON support, syntax highlighting, wget-like downloads, extensions, etc.  https://httpie.org
#
# Name: thefuck
# Owner: nvbn
# Stars: 32514
# Repository: https://github.com/nvbn/thefuck
# Created: 2015-04-08T15:08:04Z
# Updated: 2017-12-11T01:34:53Z
# Description: Magnificent app which corrects your previous console command.
#
# Name: youtube-dl
# Owner: rg3
# Stars: 31863
# Repository: https://github.com/rg3/youtube-dl
# Created: 2010-10-31T14:35:07Z
# Updated: 2017-12-11T00:20:10Z
# Description: Command-line program to download videos from YouTube.com and other video sites
#
# Name: flask
# Owner: pallets
# Stars: 31568
# Repository: https://github.com/pallets/flask
# Created: 2010-04-06T11:11:59Z
# Updated: 2017-12-11T01:16:57Z
# Description: A microframework based on Werkzeug, Jinja2 and good intentions
#
# Name: django
# Owner: django
# Stars: 30225
# Repository: https://github.com/django/django
# Created: 2012-04-28T02:47:18Z
# Updated: 2017-12-10T22:57:13Z
# Description: The Web framework for perfectionists with deadlines.
#
# Name: requests
# Owner: requests
# Stars: 29105
# Repository: https://github.com/requests/requests
# Created: 2011-02-13T18:38:17Z
# Updated: 2017-12-11T02:11:08Z
# Description: Python HTTP Requests for Humans™ ✨🍰✨
#
# Name: awesome-machine-learning
# Owner: josephmisiti
# Stars: 28208
# Repository: https://github.com/josephmisiti/awesome-machine-learning
# Created: 2014-07-15T19:11:19Z
# Updated: 2017-12-11T01:31:19Z
# Description: A curated list of awesome Machine Learning frameworks, libraries and software.
#
# Name: ansible
# Owner: ansible
# Stars: 27111
# Repository: https://github.com/ansible/ansible
# Created: 2012-03-06T14:58:02Z
# Updated: 2017-12-11T01:14:49Z
# Description: Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy. Avoid writing scripts or custom code to deploy and update your applications— automate in a language that approaches plain English, using SSH, with no agents to install on remote systems.
#
# Name: models
# Owner: tensorflow
# Stars: 24946
# Repository: https://github.com/tensorflow/models
# Created: 2016-02-05T01:15:20Z
# Updated: 2017-12-11T01:48:25Z
# Description: Models and examples built with TensorFlow
#
# Name: scrapy
# Owner: scrapy
# Stars: 24391
# Repository: https://github.com/scrapy/scrapy
# Created: 2010-02-22T02:01:14Z
# Updated: 2017-12-11T00:59:48Z
# Description: Scrapy, a fast high-level web crawling & scraping framework for Python.
#
# Name: scikit-learn
# Owner: scikit-learn
# Stars: 23581
# Repository: https://github.com/scikit-learn/scikit-learn
# Created: 2010-08-17T09:43:38Z
# Updated: 2017-12-11T00:20:45Z
# Description: scikit-learn: machine learning in Python
#
# Name: keras
# Owner: fchollet
# Stars: 22688
# Repository: https://github.com/fchollet/keras
# Created: 2015-03-28T00:35:42Z
# Updated: 2017-12-11T01:39:00Z
# Description: Deep Learning library for Python. Runs on TensorFlow, Theano, or CNTK.
#
# Name: big-list-of-naughty-strings
# Owner: minimaxir
# Stars: 22287
# Repository: https://github.com/minimaxir/big-list-of-naughty-strings
# Created: 2015-08-08T20:57:20Z
# Updated: 2017-12-10T10:07:30Z
# Description: The Big List of Naughty Strings is a list of strings which have a high probability of causing issues when used as user-input data.
#
# Name: shadowsocks
# Owner: shadowsocks
# Stars: 22232
# Repository: https://github.com/shadowsocks/shadowsocks
# Created: 2012-04-20T13:10:49Z
# Updated: 2017-12-11T01:44:09Z
# Description: None
#
# Name: system-design-primer
# Owner: donnemartin
# Stars: 21418
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2017-12-11T02:00:32Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
#
# Name: certbot
# Owner: certbot
# Stars: 20334
# Repository: https://github.com/certbot/certbot
# Created: 2014-11-12T02:52:20Z
# Updated: 2017-12-11T02:04:13Z
# Description: Certbot is EFF's tool to obtain certs from Let's Encrypt and (optionally) auto-enable HTTPS on your server.  It can also act as a client for any other CA that uses the ACME protocol.
#
# Name: XX-Net
# Owner: XX-net
# Stars: 19564
# Repository: https://github.com/XX-net/XX-Net
# Created: 2015-01-15T09:35:51Z
# Updated: 2017-12-11T01:47:40Z
# Description: a web proxy tool
#
# Name: incubator-superset
# Owner: apache
# Stars: 17088
# Repository: https://github.com/apache/incubator-superset
# Created: 2015-07-21T18:55:34Z
# Updated: 2017-12-11T01:51:52Z
# Description: Apache Superset (incubating) is a modern, enterprise-ready business intelligence web application
#
# Name: you-get
# Owner: soimort
# Stars: 16215
# Repository: https://github.com/soimort/you-get
# Created: 2012-08-20T15:53:36Z
# Updated: 2017-12-11T01:25:48Z
# Description: :arrow_double_down: Dumb downloader that scrapes the web
#
# Name: CppCoreGuidelines
# Owner: isocpp
# Stars: 15892
# Repository: https://github.com/isocpp/CppCoreGuidelines
# Created: 2015-08-19T20:22:52Z
# Updated: 2017-12-11T01:43:44Z
# Description: The C++ Core Guidelines are a set of tried-and-true guidelines, rules, and best practices about coding in C++
#
# Name: YouCompleteMe
# Owner: Valloric
# Stars: 15263
# Repository: https://github.com/Valloric/YouCompleteMe
# Created: 2012-04-16T03:12:14Z
# Updated: 2017-12-11T00:15:11Z
# Description: A code-completion engine for Vim
#
# Name: Deep-Learning-Papers-Reading-Roadmap
# Owner: songrotek
# Stars: 14957
# Repository: https://github.com/songrotek/Deep-Learning-Papers-Reading-Roadmap
# Created: 2016-10-14T11:49:48Z
# Updated: 2017-12-11T00:10:11Z
# Description: Deep Learning papers reading roadmap for anyone who are eager to learn this amazing tech!
#
# Name: sentry
# Owner: getsentry
# Stars: 14813
# Repository: https://github.com/getsentry/sentry
# Created: 2010-08-30T22:06:41Z
# Updated: 2017-12-11T02:09:24Z
# Description: Sentry is a cross-platform crash reporting and aggregation platform.
#
# Name: tornado
# Owner: tornadoweb
# Stars: 14753
# Repository: https://github.com/tornadoweb/tornado
# Created: 2009-09-09T04:55:16Z
# Updated: 2017-12-11T01:07:04Z
# Description: Tornado is a Python web framework and asynchronous networking library, originally developed at FriendFeed.
#
# Name: cpython
# Owner: python
# Stars: 14690
# Repository: https://github.com/python/cpython
# Created: 2017-02-10T19:23:51Z
# Updated: 2017-12-10T23:46:31Z
# Description: The Python programming language
#
# Name: reddit
# Owner: reddit
# Stars: 14209
# Repository: https://github.com/reddit/reddit
# Created: 2008-06-18T23:30:53Z
# Updated: 2017-12-11T01:16:07Z
# Description: historical code from reddit.com
#
# Name: python-patterns
# Owner: faif
# Stars: 13430
# Repository: https://github.com/faif/python-patterns
# Created: 2012-06-06T21:02:35Z
# Updated: 2017-12-11T01:16:09Z
# Description: A collection of design patterns/idioms in Python
#
# Name: macOS-Security-and-Privacy-Guide
# Owner: drduh
# Stars: 12511
# Repository: https://github.com/drduh/macOS-Security-and-Privacy-Guide
# Created: 2015-08-31T03:36:35Z
# Updated: 2017-12-10T23:06:45Z
# Description: A practical guide to securing macOS.
#
# Name: ipython
# Owner: ipython
# Stars: 12220
# Repository: https://github.com/ipython/ipython
# Created: 2010-05-10T04:46:06Z
# Updated: 2017-12-10T23:27:15Z
# Description: Official repository for IPython itself. Other repos in the IPython organization contain things like the website, documentation builds, etc.

# %% [markdown]
# #### Monitoring API rate limits

# %% [markdown]
# See <https://api.github.com/rate_limit> to see your rate limit info.

# %% [markdown]
# ### Visualizing repositories using Pygal

# %% [markdown]
# #### Refinging Pygal charts

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

names, stars = [], []
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

style = LS('#333366', base_style=LCS)
style.title_font_size = 24
style.label_font_size = 14
style.major_label_font_size = 18

config = pygal.Config()
config.x_label_rotation = 45
config.show_legend = False
config.truncate_label = 15
config.show_y_guides = False
config.width = 1000

chart=pygal.Bar(style=style, config=config)
chart.title = 'Most-Starred Python Projects on GitHub'
chart.x_labels = names
chart.add('', stars)
chart.render_to_file('chapter_17_output/python_repos.svg')

# %% [markdown]
# #### Adding custom tooltips

# %%
chart = pygal.Bar(style=style, config=config)
chart.title = 'Python Projects'
chart.x_labels = ['httpie', 'django', 'flask']

plot_dicts = [
    {'value': 16101, 'label': 'Description of httpie.'},
    {'value': 15028, 'label': 'Description of django..'},
    {'value': 14798, 'label': 'Description of flask.'},
]

chart.add('', plot_dicts)
chart.render_to_file('chapter_17_output/bar_descriptions.svg')

# %% [markdown]
# #### Plotting the data

# %%
chart = pygal.Bar(style=style, config=config)
chart.title = 'Most-Starred Python Projects on GitHub'

names, plot_dicts = [], []
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    description = repo_dict['description']
    if not description:
        description = 'No description provided.'
    
    plot_dicts.append({
        'value': repo_dict['stargazers_count'],
        'label': description,
    })

chart.x_labels = names
chart.add('', plot_dicts)
chart.render_to_file('chapter_17_output/python_repos_with_descriptions.svg')

# %% [markdown]
# #### Adding clickable links to our graph

# %%
chart = pygal.Bar(style=style, config=config)
chart.title = 'Most-Starred Python Projects on GitHub'

names, plot_dicts = [], []
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    description = repo_dict['description']
    if not description:
        description = 'No description provided.'
    
    plot_dicts.append({
        'value': repo_dict['stargazers_count'],
        'label': description,
        'xlink': repo_dict['html_url']
    })

chart.x_labels = names
chart.add('', plot_dicts)
chart.render_to_file('chapter_17_output/python_repos_with_descriptions_and_links.svg')

# %% [markdown]
# ### The Hacker News API

# %%
import requests

from operator import itemgetter

url_prefix = 'https://hacker-news.firebaseio.com/v0/'
url = url_prefix + 'topstories.json'
r = requests.get(url)
print('Status code:', r.status_code)

submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[:30]:
    url = url_prefix + 'item/' + str(submission_id) + '.json'
    submission_request = requests.get(url)
    print('Status code:', submission_request.status_code)
    response_dict = submission_request.json()
    
    submission_dicts.append({
        'title': response_dict['title'],
        'link': 'http://news.ycombinator.com/item?id=' + str(submission_id),
        'comments': response_dict.get('descendants', 0)
    })

submission_dicts = sorted(submission_dicts, key=itemgetter('comments'), reverse=True)

print('len', len(submission_dicts))
for submission_dict in submission_dicts:
    print('\nTitle:', submission_dict['title'])
    print('Discussion link:', submission_dict['link'])
    print('Comments:', submission_dict['comments'])
# Out:
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# len 30
#
# Title: Show HN: Airmash – Multiplayer Missile Warfare HTML5 Game
# Discussion link: http://news.ycombinator.com/item?id=15892066
# Comments: 191
#
# Title: A beginner’s guide to getting started in the cryptocurrency world
# Discussion link: http://news.ycombinator.com/item?id=15891344
# Comments: 166
#
# Title: Facebook wants your children's mind
# Discussion link: http://news.ycombinator.com/item?id=15893834
# Comments: 80
#
# Title: What Makes a Great Software Engineer? [pdf]
# Discussion link: http://news.ycombinator.com/item?id=15892898
# Comments: 72
#
# Title: Learn Anything White Paper
# Discussion link: http://news.ycombinator.com/item?id=15891340
# Comments: 55
#
# Title: Project Euler
# Discussion link: http://news.ycombinator.com/item?id=15893911
# Comments: 51
#
# Title: CBOE exchange website down minutes after releasing Bitcoin futures
# Discussion link: http://news.ycombinator.com/item?id=15894062
# Comments: 45
#
# Title: Amazon delivery drivers complain about bad work conditions
# Discussion link: http://news.ycombinator.com/item?id=15893828
# Comments: 28
#
# Title: A simple DIY Heroku replacement to keep your hosting costs down
# Discussion link: http://news.ycombinator.com/item?id=15892617
# Comments: 27
#
# Title: Apple ‘On Schedule’ to Terminate Music Downloads by 2019
# Discussion link: http://news.ycombinator.com/item?id=15894827
# Comments: 26
#
# Title: Show HN: Enlight – Learn to code by building projects
# Discussion link: http://news.ycombinator.com/item?id=15892554
# Comments: 23
#
# Title: Finding bugs in Haskell code by proving it
# Discussion link: http://news.ycombinator.com/item?id=15891599
# Comments: 20
#
# Title: Supplying Legal Notices for Free Software in your Products
# Discussion link: http://news.ycombinator.com/item?id=15893348
# Comments: 19
#
# Title: Does Life End at 35? (2013)
# Discussion link: http://news.ycombinator.com/item?id=15894396
# Comments: 18
#
# Title: NASA to test prototype Kilopower nuclear reactor
# Discussion link: http://news.ycombinator.com/item?id=15894303
# Comments: 18
#
# Title: Turning Vim into an R IDE
# Discussion link: http://news.ycombinator.com/item?id=15894162
# Comments: 13
#
# Title: Maintenance often matters more than innovation (2016)
# Discussion link: http://news.ycombinator.com/item?id=15892808
# Comments: 12
#
# Title: Calculating Burn Rates in J
# Discussion link: http://news.ycombinator.com/item?id=15890189
# Comments: 11
#
# Title: Show HN: MIDI chat over WebRTC
# Discussion link: http://news.ycombinator.com/item?id=15891788
# Comments: 9
#
# Title: Design Principles
# Discussion link: http://news.ycombinator.com/item?id=15894400
# Comments: 6
#
# Title: I had a boss who stood up for me against sexist office jerks
# Discussion link: http://news.ycombinator.com/item?id=15894242
# Comments: 6
#
# Title: Show HN: cmus-osx – Tightly integrates cmus command line music player into macOS
# Discussion link: http://news.ycombinator.com/item?id=15893214
# Comments: 6
#
# Title: AWS DNS services break qname minimization
# Discussion link: http://news.ycombinator.com/item?id=15893103
# Comments: 5
#
# Title: World's Largest Water Diversion Plan Won't Quench China's Thirst
# Discussion link: http://news.ycombinator.com/item?id=15894010
# Comments: 4
#
# Title: The Mathematics of 2048: Counting States by Exhaustive Enumeration
# Discussion link: http://news.ycombinator.com/item?id=15894126
# Comments: 3
#
# Title: Apache Kafka – Scaling SQL with KStream and Kafka Connect
# Discussion link: http://news.ycombinator.com/item?id=15893909
# Comments: 3
#
# Title: Kenya is using the earth's heat to power the country
# Discussion link: http://news.ycombinator.com/item?id=15894376
# Comments: 2
#
# Title: The Lives of a Cell: Notes of a Biology Watcher (1974) [pdf]
# Discussion link: http://news.ycombinator.com/item?id=15893232
# Comments: 2
#
# Title: Jeff Dean: Machine Learning for Systems [pdf]
# Discussion link: http://news.ycombinator.com/item?id=15892956
# Comments: 2
#
# Title: Dasynq – the event-loop library
# Discussion link: http://news.ycombinator.com/item?id=15893791
# Comments: 0

# %% [markdown]
# #### Try it yourself

# %%
# 17-1. Other languages: Modify the API call in python_repos.py so it
# generates a chart showing the most popular projects in other languages.
# Try languages such as JavaScript, Ruby, C, Java, Perl, haskell and Go.

for language in ['js', 'ruby', 'c', 'java', 'perl', 'haskell', 'go']:
    url = 'https://api.github.com/search/repositories?q=language:' + language + '&sort=starts'
    r = requests.get(url)
    response_dict = r.json()
    repo_dicts = response_dict['items']

    chart = pygal.Bar(style=style, config=config)
    chart.title = 'Most-Starred ' + language.title() + ' Projects on GitHub'

    names, plot_dicts = [], []
    for repo_dict in repo_dicts:
        names.append(repo_dict['name'])
        description = repo_dict['description']
        if not description:
            description = 'No description provided.'

        plot_dicts.append({
            'value': repo_dict['stargazers_count'],
            'label': description,
            'xlink': repo_dict['html_url']
        })

    chart.x_labels = names
    chart.add('', plot_dicts)
    chart.render_to_file('chapter_17_output/' + language + '_repos_with_descriptions_and_links.svg')

# %%
# 17-2. Active discussions: Using the data from hn_submissions.py, make a bar
# chart showing the most active discussions currently happening on Hacker News.
# The height of each bar should correspond to the number of comments each
# submission has. The label for each bar should include the submission's title,
# and each bar should act as a link to the discussion page for that submission.

chart = pygal.Bar(style=style, config=config)
chart.title = 'Most active discussions currently on Hacker News'

titles, plot_dicts = [], []
for submission_dict in submission_dicts:
    title = submission_dict['title']
    titles.append(title)
    plot_dicts.append({
        'value': submission_dict['comments'],
        'label': title,
        'xlink': submission_dict['link']
    })

chart.x_labels = titles
chart.add('', plot_dicts)
chart.render_to_file('chapter_17_output/most_active_discussions_on_hn.svg')
